# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scipy.stats as stats

# %%
hours = np.array([1, 2, 2, 3, 5, 4, 6, 8, 7, 9])
scores = hours * 10 + np.random.normal(0, 5, size=hours.shape)
print("Hours studied:", hours)
print("Scores obtained:", scores)
# Out:
# Hours studied: [1 2 2 3 5 4 6 8 7 9]
# Scores obtained: [13.75565067  5.06214586 19.01127884 33.79845972 60.94881002 45.34015236
#  55.2104556  80.55661464 70.03460843 77.79288276]

# %%
df = pd.DataFrame({'Hours': hours, 'Scores': scores})
df.head()
# Out:
#    Hours     Scores
# 0      1  13.755651
# 1      2   5.062146
# 2      2  19.011279
# 3      3  33.798460
# 4      5  60.948810

# %%
r = stats.pearsonr(df['Hours'], df['Scores'])[0]
print(f"Pearson correlation coefficient: {r:.2f}")
p_value = stats.pearsonr(df['Hours'], df['Scores'])[1]
print(f"P-value: {p_value:.4f}")
# Out:
# Pearson correlation coefficient: 0.96
# P-value: 0.0000

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Hours', y='Scores', data=df, s=100)
plt.title('Scatter Plot of Hours Studied vs. Scores Obtained')
plt.xlabel('Hours Studied')
plt.ylabel('Scores Obtained')
plt.show()

# %%
price_chances = np.array([-20, -15, -10, -5, 0, 5, 10, 15, 20])
sales_volumes = 1000 - 2 * price_chances + np.random.normal(0, 30, size=price_chances.shape)
df = pd.DataFrame({'Price_Changes': price_chances, 'Sales_Volumes': sales_volumes})
df.head()
# Out:
#    Price_Changes  Sales_Volumes
# 0            -20    1046.283665
# 1            -15    1103.845884
# 2            -10    1055.513861
# 3             -5     989.967292
# 4              0    1011.938284

# %%
r = stats.pearsonr(df['Price_Changes'], df['Sales_Volumes'])[0]
print(f"Pearson correlation coefficient: {r:.2f}")
# Out:
# Pearson correlation coefficient: -0.91

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Price_Changes', y='Sales_Volumes', data=df, s=100)
plt.title('Scatter Plot of Price Changes vs. Sales Volume')
plt.xlabel('Price Changes')
plt.ylabel('Sales Volume')
plt.show()

# %%
df = pd.read_csv('df.csv')
df.head()
# Out:
#        ID                                 Name    State     Region  \
# 0  100654             Alabama A & M University  Alabama  Southeast
# 1  100663  University of Alabama at Birmingham  Alabama  Southeast
# 2  100706  University of Alabama in Huntsville  Alabama  Southeast
# 3  100724             Alabama State University  Alabama  Southeast
# 4  100751            The University of Alabama  Alabama  Southeast
#
#    Applications  Admissions  Admission Rate  Enrollment  SATVR75  SATMT75  \
# 0          6560        4697        0.716006        1459    520.0    510.0
# 1         11906       10541        0.885352        2361    680.0    708.0
# 2          5781        4259        0.736724        1191    700.0    720.0
# 3          5974        5854        0.979913         797    534.0    516.0
# 4         42421       33472        0.789043        7540    680.0    690.0
#
#    ACTEN75  ACTMT75
# 0     20.0     18.0
# 1     33.0     28.0
# 2     32.0     29.0
# 3     22.0     19.0
# ...

# %%
df = df.dropna()
selected_columns = ['Applications','Admissions','Admission Rate','Enrollment','SATVR75','SATMT75','ACTEN75','ACTMT75']
correlation_matrix = df[selected_columns].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()
