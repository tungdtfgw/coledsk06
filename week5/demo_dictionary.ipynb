# %%
# dictionary is collection of key-value pairs
# keys are unique and immutable
# values can be accessed via keys
en_vn = {'apple': 'quả táo', 'banana': 'quả chuối', 'orange': 'quả cam'}

# %%
print(en_vn['apple'])  # Output: quả táo
# Out:
# quả táo

# %%
print(en_vn['banana'])  # Output: quả chuối
# Out:
# quả chuối

# %%
print(en_vn['kiwi'])  # KeyError: 'kiwi'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(en_vn['kiwi'])  # KeyError: 'kiwi'
#
# KeyError: 'kiwi'

# %%
fruit = input('Enter a fruit in English: ')
if fruit in en_vn:
    print(f'Vietnamese fruit: {en_vn[fruit]}')
else:
    print('Sorry I dont know that word')
# Out:
# Sorry I dont know that word

# %%
print(en_vn)
# Out:
# {'apple': 'quả táo', 'banana': 'quả chuối', 'orange': 'quả cam'}

# %%
# insert a new word
en_vn['mango'] = 'quả xoài'
print(en_vn)
# Out:
# {'apple': 'quả táo', 'banana': 'quả chuối', 'orange': 'quả cam', 'mango': 'quả xoài'}

# %%
en_vn['durian'] = 'quả xầu riêng'
print(en_vn)
# Out:
# {'apple': 'quả táo', 'banana': 'quả chuối', 'orange': 'quả cam', 'mango': 'quả xoài', 'durian': 'quả xầu riêng'}

# %%
en_vn['durian'] = 'quả sầu riêng'
print(en_vn)
# Out:
# {'apple': 'quả táo', 'banana': 'quả chuối', 'orange': 'quả cam', 'mango': 'quả xoài', 'durian': 'quả sầu riêng'}

# %%
# insert new word
new_fruit = input('Enter a new fruit in English: ')
if new_fruit not in en_vn:
    trans = input(f'Enter the Vietnamese translation for {new_fruit}: ')
    en_vn[new_fruit] = trans
    print('Updated dictionary:', en_vn)
else:
    print(f'{new_fruit} already exists in the dictionary.')
# Out:
# Updated dictionary: {'apple': 'quả táo', 'banana': 'quả chuối', 'orange': 'quả cam', 'mango': 'quả xoài', 'durian': 'quả sầu riêng', 'kiwi': 'kiwi'}

# %%
del en_vn['orange']
print(en_vn)
# Out:
# {'apple': 'quả táo', 'banana': 'quả chuối', 'mango': 'quả xoài', 'durian': 'quả sầu riêng', 'kiwi': 'kiwi'}

# %%
fruit = en_vn.pop('banana')
print(en_vn)
print('Removed fruit:', fruit)
# Out:
# {'apple': 'quả táo', 'mango': 'quả xoài', 'durian': 'quả sầu riêng', 'kiwi': 'kiwi'}
# Removed fruit: quả chuối

# %%
# get all keys:
print(list(en_vn.keys()))
# get all values:
print(list(en_vn.values()))
# get all items
print(list(en_vn.items()))
# Out:
# ['apple', 'mango', 'durian', 'kiwi']
# ['quả táo', 'quả xoài', 'quả sầu riêng', 'kiwi']
# [('apple', 'quả táo'), ('mango', 'quả xoài'), ('durian', 'quả sầu riêng'), ('kiwi', 'kiwi')]

# %%
for fruit, fruit_vn in en_vn.items():
    print(f'{fruit} => {fruit_vn}')
# Out:
# apple => quả táo
# mango => quả xoài
# durian => quả sầu riêng
# kiwi => kiwi
